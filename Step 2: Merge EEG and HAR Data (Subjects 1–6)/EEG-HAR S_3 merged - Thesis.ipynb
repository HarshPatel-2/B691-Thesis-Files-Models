# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import glob

# %% [markdown]
# # Load EEG Files for Subject 3

# %%
column_names = [
    "Sample Index", "EXG Channel 0", "EXG Channel 1", "EXG Channel 2", "EXG Channel 3",
    "EXG Channel 4", "EXG Channel 5", "EXG Channel 6", "EXG Channel 7", "EXG Channel 8",
    "EXG Channel 9", "EXG Channel 10", "EXG Channel 11", "EXG Channel 12", "EXG Channel 13",
    "EXG Channel 14", "EXG Channel 15", "Accel Channel 0", "Accel Channel 1", "Accel Channel 2",
    "Not Used 1", "Digital Channel 0 (D11)", "Digital Channel 1 (D12)", "Digital Channel 2 (D13)",
    "Digital Channel 3 (D17)", "Not Used 2", "Digital Channel 4 (D18)", "Analog Channel 0",
    "Analog Channel 1", "Analog Channel 2", "Timestamp", "Marker Channel", "Timestamp (Formatted)"
]

eeg_files = sorted(glob.glob("/data0/HAR-datasets/PLHI-HAR_EEG-2025/OpenBCISession_s3-*/BrainFlow-RAW_s3-*.csv"))

def load_eeg(file):
    df = pd.read_csv(file, sep="\t", skiprows=3, names=column_names, engine="python")
    df["Activity"] = file.split("/")[-2]
    return df

eeg_df_list = [load_eeg(file) for file in eeg_files]
eeg_df = pd.concat(eeg_df_list, ignore_index=True)

print(f"Successfully loaded {len(eeg_files)} EEG files for Subject 3 across all activities.")
print("Unique activities in EEG data:", eeg_df["Activity"].unique())
display(eeg_df.head())
# Out:
# Successfully loaded 51 EEG files for Subject 3 across all activities.
# Unique activities in EEG data: ['OpenBCISession_s3-chair squats'
#  'OpenBCISession_s3-light stationary cycling'
#  'OpenBCISession_s3-marching in place'
#  'OpenBCISession_s3-seated boxing hooks'
#  'OpenBCISession_s3-seated leg extensions'
#  'OpenBCISession_s3-seated medicine ball twists'
#  'OpenBCISession_s3-seated side bends' 'OpenBCISession_s3-side-stepping'
#  'OpenBCISession_s3-standing heel to toe walk'
#  'OpenBCISession_s3-wall push-ups']
# /tmp/ipykernel_589559/3103348099.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   eeg_df = pd.concat(eeg_df_list, ignore_index=True)
#    Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  EXG Channel 3  \
# 0           6.0 -187500.022352 -155254.479379 -187500.022352 -187500.022352
# 1           8.0 -187500.022352 -157397.207009 -187500.022352 -187500.022352
# 2          10.0 -187500.022352 -159525.651875 -187500.022352 -187500.022352
# 3          12.0 -187500.022352 -161934.789948 -187500.022352 -187500.022352
# 4          14.0 -187500.022352 -164294.776534 -187500.022352 -187500.022352
#
#    EXG Channel 4  EXG Channel 5  EXG Channel 6  EXG Channel 7  EXG Channel 8  \
# 0 -187500.022352 -175090.490292 -187500.022352 -185935.847275 -187500.022352
# 1 -187500.022352 -177446.051234 -187500.022352 -187002.271354 -187500.022352
# 2 -187500.022352 -180172.829947 -187500.022352 -187500.022352 -187500.022352
# 3 -187500.022352 -183174.423358 -187500.022352 -187500.022352 -187500.022352
# 4 -187500.022352 -185787.878726 -187500.022352 -187500.022352 -187500.022352
#
#    ...  Digital Channel 3 (D17)  Not Used 2  Digital Channel 4 (D18)  \
# 0  ...                      0.0         0.0                      0.0
# 1  ...                     64.0       123.5                    104.0
# 2  ...                      0.0         0.0                      0.0
# 3  ...                      0.0         0.0                      0.0
# 4  ...                      0.0         0.0                      0.0
#
#    Analog Channel 0  Analog Channel 1  Analog Channel 2     Timestamp  \
# 0               0.0               0.0               0.0  1.739041e+09
# 1               0.0               0.0               0.0  1.739041e+09
# 2               0.0               0.0               0.0  1.739041e+09
# 3               0.0               0.0               0.0  1.739041e+09
# 4               0.0               0.0               0.0  1.739041e+09
#
#    Marker Channel  Timestamp (Formatted)                        Activity
# 0             0.0                    NaN  OpenBCISession_s3-chair squats
# 1             0.0                    NaN  OpenBCISession_s3-chair squats
# 2             0.0                    NaN  OpenBCISession_s3-chair squats
# 3             0.0                    NaN  OpenBCISession_s3-chair squats
# 4             0.0                    NaN  OpenBCISession_s3-chair squats
#
# [5 rows x 34 columns]

# %% [markdown]
# # Display Last Rows of EEG Data

# %%
display(eeg_df.tail())
# Out:
#         Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  \
# 562557          72.0 -187500.022352 -110910.339464 -130249.515802
# 562558          74.0 -187500.022352 -108958.853359 -128249.481708
# 562559          76.0 -187500.022352 -107532.297973 -126866.400464
# 562560           0.0 -187500.022352 -105450.724715 -124850.429577
# 562561          80.0 -187500.022352 -103850.384516 -123500.317156
#
#         EXG Channel 3  EXG Channel 4  EXG Channel 5  EXG Channel 6  \
# 562557 -163310.361005 -142283.091519   55486.596285   22283.146952
# 562558 -161600.787830 -139991.300105   58058.030374   22235.895364
# 562559 -160453.629250 -138229.066220   60023.396912   22172.796389
# 562560 -158814.397015 -135875.919268   61751.700849   22041.546946
# 562561 -157610.688521 -134251.685053   62791.347538   22095.079374
#
#         EXG Channel 7  EXG Channel 8  ...  Digital Channel 3 (D17)  \
# 562557 -172645.567077   21344.977182  ...                      0.0
# 562558 -170722.333577   20932.632200  ...                      0.0
# 562559 -169197.117591   21173.896929  ...                    104.0
# 562560 -167246.011465       0.000000  ...                      0.0
# 562561 -165736.419348   21041.865175  ...                      0.0
#
#         Not Used 2  Digital Channel 4 (D18)  Analog Channel 0  \
# 562557         0.0                      0.0               0.0
# 562558         0.0                      0.0               0.0
# 562559         8.0                     80.0               0.0
# 562560         0.0                      0.0               0.0
# 562561         0.0                      0.0               0.0
#
#         Analog Channel 1  Analog Channel 2     Timestamp  Marker Channel  \
# 562557               0.0               0.0  1.739039e+09             0.0
# 562558               0.0               0.0  1.739039e+09             0.0
# 562559               0.0               0.0  1.739039e+09             0.0
# 562560               0.0               0.0  1.739039e+09             0.0
# 562561               0.0               0.0  1.739039e+09             0.0
#
#         Timestamp (Formatted)                         Activity
# 562557                    NaN  OpenBCISession_s3-wall push-ups
# 562558                    NaN  OpenBCISession_s3-wall push-ups
# 562559                    NaN  OpenBCISession_s3-wall push-ups
# 562560                    NaN  OpenBCISession_s3-wall push-ups
# 562561                    NaN  OpenBCISession_s3-wall push-ups
#
# [5 rows x 34 columns]

# %% [markdown]
# # Extract EEG Start and End Timestamps

# %%
eeg_timestamps = eeg_df[['Timestamp', 'Marker Channel']]
start_time = eeg_timestamps['Timestamp'].min()
end_time = eeg_timestamps['Timestamp'].max()
print(f" Extracted EEG activity start and end timestamps:")
print(f" Start Timestamp: {start_time}")
print(f" End Timestamp: {end_time}")
# Out:
#  Extracted EEG activity start and end timestamps:
#  Start Timestamp: 1739038165.76315
#  End Timestamp: 1739042219.014381

# %% [markdown]
# # Load and Filter HAR Data for Subject 3

# %%
har_file_path = "/data0/HAR-datasets/PLHI-HAR_EEG-2025/Combined_Gyro_Acg_Data_Subjects_1_to_6.csv"
har_df = pd.read_csv(har_file_path)

har_df['Timestamp_Accel'] = pd.to_numeric(har_df['Timestamp_Accel'], errors='coerce')
har_df['Timestamp_Gyro'] = pd.to_numeric(har_df['Timestamp_Gyro'], errors='coerce')

if har_df['Timestamp_Accel'].max() > 1e12:  
    har_df['Timestamp_Accel'] = har_df['Timestamp_Accel'] / 1000
    har_df['Timestamp_Gyro'] = har_df['Timestamp_Gyro'] / 1000

print("Before filtering:", har_df.shape)
har_df = har_df[har_df['Subject_ID_x'] == "Subject 3"]
print("After filtering:", har_df.shape)

valid_har = har_df[
    (har_df['Timestamp_Accel'].between(start_time, end_time)) |
    (har_df['Timestamp_Gyro'].between(start_time, end_time))
]

filtered_har = valid_har

print("HAR data is clipped to the EEG activity time range. All activities for Subject 3 are included.")
display(filtered_har.head())
# Out:
# Before filtering: (944460, 12)
# After filtering: (186349, 12)
# HAR data is clipped to the EEG activity time range. All activities for Subject 3 are included.
# /tmp/ipykernel_589559/3318848402.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   har_df = pd.read_csv(har_file_path)
#         Timestamp_Gyro  Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)  \
# 361490    1.739038e+09     -0.693943      -0.73426     -0.262672
# 361491    1.739038e+09     -0.693943      -0.73426     -0.262672
# 361492    1.739038e+09     -0.693943      -0.73426     -0.262672
# 361493    1.739038e+09     -0.693943      -0.73426     -0.262672
# 361494    1.739038e+09     -0.693943      -0.73426     -0.262672
#
#              Activity_Label_x Subject_ID_x  Timestamp_Accel  Accel X (g)  \
# 361490  Seated Leg Extensions    Subject 3     1.739038e+09     2.892196
# 361491  Seated Leg Extensions    Subject 3     1.739038e+09     2.892196
# 361492  Seated Leg Extensions    Subject 3     1.739038e+09     2.892196
# 361493  Seated Leg Extensions    Subject 3     1.739038e+09     2.892196
# 361494  Seated Leg Extensions    Subject 3     1.739038e+09     2.892196
#
#        Accel Y (g)  Accel Z (g)       Activity_Label_y Subject_ID_y
# 361490    -4.36463    10.012551  Seated Leg Extensions    Subject 3
# 361491    -4.36463    10.012551  Seated Leg Extensions    Subject 3
# 361492    -4.36463    10.012551  Seated Leg Extensions    Subject 3
# 361493    -4.36463    10.012551  Seated Leg Extensions    Subject 3
# 361494    -4.36463    10.012551  Seated Leg Extensions    Subject 3

# %% [markdown]
# # Display Shape and Info of Filtered HAR Data

# %%
print(filtered_har.shape) 
print(filtered_har.info())
# Out:
# (186348, 12)
# <class 'pandas.core.frame.DataFrame'>
# Index: 186348 entries, 361490 to 547838
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Timestamp_Gyro    186348 non-null  float64
#  1   Gyro X (°/s)      186348 non-null  float64
#  2   Gyro Y (°/s)      186312 non-null  float64
#  3   Gyro Z (°/s)      186301 non-null  float64
#  4   Activity_Label_x  186348 non-null  object
#  5   Subject_ID_x      186348 non-null  object
#  6   Timestamp_Accel   186348 non-null  float64
#  7   Accel X (g)       186348 non-null  float64
#  8   Accel Y (g)       186328 non-null  object
#  9   Accel Z (g)       186328 non-null  float64
#  10  Activity_Label_y  186348 non-null  object
#  11  Subject_ID_y      186348 non-null  object
# dtypes: float64(7), object(5)
# memory usage: 18.5+ MB
# None

# %% [markdown]
# # Merge EEG and HAR Data by Timestamp

# %%
eeg_df_sorted = eeg_df.sort_values("Timestamp")
har_df_sorted = filtered_har.sort_values("Timestamp_Accel")

merged_df = pd.merge_asof(
    eeg_df_sorted, 
    har_df_sorted, 
    left_on="Timestamp", 
    right_on="Timestamp_Accel", 
    direction="nearest"
)

print(" EEG & HAR merged.")
display(merged_df.head())
# Out:
#  EEG & HAR merged.
#    Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  EXG Channel 3  \
# 0           6.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 1           8.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 2          10.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 3          12.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 4          14.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
#
#    EXG Channel 4  EXG Channel 5  EXG Channel 6  EXG Channel 7  EXG Channel 8  \
# 0 -187500.022352 -183210.432018   22146.935421 -187500.022352   28596.352469
# 1 -187500.022352 -183222.211387   22380.846427 -187500.022352   28492.729782
# 2 -187500.022352 -183295.390999   22193.583512 -187500.022352   28642.106490
# 3 -187500.022352 -183051.108784   22374.275014 -187500.022352   28487.499474
# 4 -187500.022352 -183158.352454   22160.659392 -187500.022352   28649.862546
#
#    ...  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_x  Subject_ID_x  \
# 0  ...      -0.73426     -0.262672  Seated Leg Extensions     Subject 3
# 1  ...      -0.73426     -0.262672  Seated Leg Extensions     Subject 3
# 2  ...      -0.73426     -0.262672  Seated Leg Extensions     Subject 3
# 3  ...      -0.73426     -0.262672  Seated Leg Extensions     Subject 3
# 4  ...      -0.73426     -0.262672  Seated Leg Extensions     Subject 3
#
#    Timestamp_Accel  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0     1.739038e+09     2.892196     -4.36463    10.012551
# 1     1.739038e+09     2.892196     -4.36463    10.012551
# 2     1.739038e+09     2.892196     -4.36463    10.012551
# 3     1.739038e+09     2.892196     -4.36463    10.012551
# 4     1.739038e+09     2.892196     -4.36463    10.012551
#
#         Activity_Label_y  Subject_ID_y
# 0  Seated Leg Extensions     Subject 3
# 1  Seated Leg Extensions     Subject 3
# 2  Seated Leg Extensions     Subject 3
# 3  Seated Leg Extensions     Subject 3
# 4  Seated Leg Extensions     Subject 3
#
# [5 rows x 46 columns]

# %% [markdown]
# # Check Timestamp Alignment

# %%
print("Timestamp alignment (EEG vs HAR):")
print(merged_df[['Timestamp', 'Timestamp_Accel']])
# Out:
# Timestamp alignment (EEG vs HAR):
#            Timestamp  Timestamp_Accel
# 0       1.739038e+09     1.739038e+09
# 1       1.739038e+09     1.739038e+09
# 2       1.739038e+09     1.739038e+09
# 3       1.739038e+09     1.739038e+09
# 4       1.739038e+09     1.739038e+09
# ...              ...              ...
# 562557  1.739042e+09     1.739042e+09
# 562558  1.739042e+09     1.739042e+09
# 562559  1.739042e+09     1.739042e+09
# 562560  1.739042e+09     1.739042e+09
# 562561  1.739042e+09     1.739042e+09
#
# [562562 rows x 2 columns]

# %% [markdown]
# # Show Merged Data Columns

# %%
print("Unique Columns in Merged Data:")
print(merged_df.columns)
# Out:
# Unique Columns in Merged Data:
# Index(['Sample Index', 'EXG Channel 0', 'EXG Channel 1', 'EXG Channel 2',
#        'EXG Channel 3', 'EXG Channel 4', 'EXG Channel 5', 'EXG Channel 6',
#        'EXG Channel 7', 'EXG Channel 8', 'EXG Channel 9', 'EXG Channel 10',
#        'EXG Channel 11', 'EXG Channel 12', 'EXG Channel 13', 'EXG Channel 14',
#        'EXG Channel 15', 'Accel Channel 0', 'Accel Channel 1',
#        'Accel Channel 2', 'Not Used 1', 'Digital Channel 0 (D11)',
#        'Digital Channel 1 (D12)', 'Digital Channel 2 (D13)',
#        'Digital Channel 3 (D17)', 'Not Used 2', 'Digital Channel 4 (D18)',
#        'Analog Channel 0', 'Analog Channel 1', 'Analog Channel 2', 'Timestamp',
#        'Marker Channel', 'Timestamp (Formatted)', 'Activity', 'Timestamp_Gyro',
#        'Gyro X (°/s)', 'Gyro Y (°/s)', 'Gyro Z (°/s)', 'Activity_Label_x',
#        'Subject_ID_x', 'Timestamp_Accel', 'Accel X (g)', 'Accel Y (g)',
#        'Accel Z (g)', 'Activity_Label_y', 'Subject_ID_y'],
#       dtype='object')

# %% [markdown]
# # Display Final Merged Data

# %%
display(merged_df)
# Out:
#         Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  \
# 0                6.0 -187500.022352 -187500.022352 -187500.022352
# 1                8.0 -187500.022352 -187500.022352 -187500.022352
# 2               10.0 -187500.022352 -187500.022352 -187500.022352
# 3               12.0 -187500.022352 -187500.022352 -187500.022352
# 4               14.0 -187500.022352 -187500.022352 -187500.022352
# ...              ...            ...            ...            ...
# 562557         128.0 -187500.022352 -187500.022352 -187500.022352
# 562558         128.0 -187500.022352 -187500.022352 -187500.022352
# 562559         128.0 -187500.022352 -187500.022352 -187500.022352
# 562560         128.0 -187500.022352 -187500.022352 -187500.022352
# 562561         128.0 -187500.022352 -187500.022352 -187500.022352
#
#         EXG Channel 3  EXG Channel 4  EXG Channel 5  EXG Channel 6  \
# 0      -187500.022352 -187500.022352 -183210.432018   22146.935421
# 1      -187500.022352 -187500.022352 -183222.211387   22380.846427
# 2      -187500.022352 -187500.022352 -183295.390999   22193.583512
# 3      -187500.022352 -187500.022352 -183051.108784   22374.275014
# 4      -187500.022352 -187500.022352 -183158.352454   22160.659392
# ...               ...            ...            ...            ...
# 562557 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 562558 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 562559 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 562560 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 562561 -187500.022352 -187500.022352 -187500.022352 -187500.022352
#
#         EXG Channel 7  EXG Channel 8  ...  Gyro Y (°/s)  Gyro Z (°/s)  \
# 0      -187500.022352   28596.352469  ...     -0.734260     -0.262672
# 1      -187500.022352   28492.729782  ...     -0.734260     -0.262672
# 2      -187500.022352   28642.106490  ...     -0.734260     -0.262672
# 3      -187500.022352   28487.499474  ...     -0.734260     -0.262672
# 4      -187500.022352   28649.862546  ...     -0.734260     -0.262672
# ...               ...            ...  ...           ...           ...
# 562557 -187500.022352 -187500.022352  ...      0.179594     -0.215025
# 562558 -187500.022352 -187500.022352  ...      0.179594     -0.215025
# 562559 -187500.022352 -187500.022352  ...      0.179594     -0.215025
# 562560 -187500.022352 -187500.022352  ...      0.179594     -0.215025
# 562561 -187500.022352 -187500.022352  ...      0.179594     -0.215025
#
#              Activity_Label_x  Subject_ID_x  Timestamp_Accel  Accel X (g)  \
# 0       Seated Leg Extensions     Subject 3     1.739038e+09     2.892196
# 1       Seated Leg Extensions     Subject 3     1.739038e+09     2.892196
# 2       Seated Leg Extensions     Subject 3     1.739038e+09     2.892196
# 3       Seated Leg Extensions     Subject 3     1.739038e+09     2.892196
# 4       Seated Leg Extensions     Subject 3     1.739038e+09     2.892196
# ...                       ...           ...              ...          ...
# 562557      Marching in Place     Subject 3     1.739042e+09     0.993594
# 562558      Marching in Place     Subject 3     1.739042e+09     0.993594
# 562559      Marching in Place     Subject 3     1.739042e+09     0.993594
# 562560      Marching in Place     Subject 3     1.739042e+09     0.993594
# 562561      Marching in Place     Subject 3     1.739042e+09     0.993594
#
#         Accel Y (g)  Accel Z (g)       Activity_Label_y  Subject_ID_y
# 0          -4.36463    10.012551  Seated Leg Extensions     Subject 3
# 1          -4.36463    10.012551  Seated Leg Extensions     Subject 3
# 2          -4.36463    10.012551  Seated Leg Extensions     Subject 3
# 3          -4.36463    10.012551  Seated Leg Extensions     Subject 3
# 4          -4.36463    10.012551  Seated Leg Extensions     Subject 3
# ...             ...          ...                    ...           ...
# 562557     3.102886     8.947132      Marching in Place     Subject 3
# 562558     3.102886     8.947132      Marching in Place     Subject 3
# 562559     3.102886     8.947132      Marching in Place     Subject 3
# 562560     3.102886     8.947132      Marching in Place     Subject 3
# 562561     3.102886     8.947132      Marching in Place     Subject 3
#
# [562562 rows x 46 columns]

# %% [markdown]
# # Save Merged Data to CSV

# %%
try:
    merged_df.to_csv("EEG-HAR_Subject_3_Merged.csv", index=False)
    print("File saved successfully as EEG-HAR_Subject_3_Merged.csv.")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")
# Out:
# File saved successfully as EEG-HAR_Subject_3_Merged.csv.
