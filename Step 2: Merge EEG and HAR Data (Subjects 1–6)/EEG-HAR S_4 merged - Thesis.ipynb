# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import glob

# %% [markdown]
# # Load EEG Files for Subject 4

# %%
column_names = [
    "Sample Index", "EXG Channel 0", "EXG Channel 1", "EXG Channel 2", "EXG Channel 3",
    "EXG Channel 4", "EXG Channel 5", "EXG Channel 6", "EXG Channel 7", "EXG Channel 8",
    "EXG Channel 9", "EXG Channel 10", "EXG Channel 11", "EXG Channel 12", "EXG Channel 13",
    "EXG Channel 14", "EXG Channel 15", "Accel Channel 0", "Accel Channel 1", "Accel Channel 2",
    "Not Used 1", "Digital Channel 0 (D11)", "Digital Channel 1 (D12)", "Digital Channel 2 (D13)",
    "Digital Channel 3 (D17)", "Not Used 2", "Digital Channel 4 (D18)", "Analog Channel 0",
    "Analog Channel 1", "Analog Channel 2", "Timestamp", "Marker Channel", "Timestamp (Formatted)"
]

eeg_files = sorted(glob.glob("/data0/HAR-datasets/PLHI-HAR_EEG-2025/OpenBCISession_s4-*/BrainFlow-RAW_s4-*.csv"))

def load_eeg(file):
    df = pd.read_csv(file, sep="\t", skiprows=3, names=column_names, engine="python")
    df["Activity"] = file.split("/")[-2]
    return df

eeg_df_list = [load_eeg(file) for file in eeg_files]
eeg_df = pd.concat(eeg_df_list, ignore_index=True)

print(f"Successfully loaded {len(eeg_files)} EEG files for Subject 4 across all activities.")
print("Unique activities in EEG data:", eeg_df["Activity"].unique())
display(eeg_df.head())
# Out:
# Successfully loaded 50 EEG files for Subject 4 across all activities.
# Unique activities in EEG data: ['OpenBCISession_s4-chair squats'
#  'OpenBCISession_s4-light stationary cycling'
#  'OpenBCISession_s4-marching in place'
#  'OpenBCISession_s4-seated boxing hooks'
#  'OpenBCISession_s4-seated leg extensions'
#  'OpenBCISession_s4-seated medicine ball twists'
#  'OpenBCISession_s4-seated side bends' 'OpenBCISession_s4-side-stepping'
#  'OpenBCISession_s4-standing heel to toe walk'
#  'OpenBCISession_s4-wall push-ups']
#    Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  EXG Channel 3  \
# 0           6.0 -187500.022352 -187500.022352  -55956.787581 -187500.022352
# 1           8.0 -187500.022352 -187500.022352  -55974.333700 -187500.022352
# 2          10.0 -187500.022352 -187500.022352  -57272.970053 -187500.022352
# 3          12.0 -187500.022352 -187500.022352  -56677.966616 -187500.022352
# 4          14.0 -187500.022352 -187500.022352  -59069.402107 -187500.022352
#
#    EXG Channel 4  EXG Channel 5  EXG Channel 6  EXG Channel 7  EXG Channel 8  \
# 0 -187500.022352  -51450.430030  -69029.764119 -187500.022352  -81732.975749
# 1 -187500.022352  -51236.926167  -69619.939580 -187500.022352  -78892.024325
# 2 -187500.022352  -52769.205304  -70386.850284 -187500.022352  -82665.781100
# 3 -187500.022352  -52102.050436  -70274.666879 -187500.022352  -79903.329003
# 4 -187500.022352  -54448.603624  -72328.278104 -187500.022352  -83850.423557
#
#    ...  Digital Channel 3 (D17)  Not Used 2  Digital Channel 4 (D18)  \
# 0  ...                      0.0         0.0                      0.0
# 1  ...                    104.0         3.0                     80.0
# 2  ...                      0.0         0.0                      0.0
# 3  ...                      0.0         0.0                      0.0
# 4  ...                      0.0         0.0                      0.0
#
#    Analog Channel 0  Analog Channel 1  Analog Channel 2     Timestamp  \
# 0               0.0               0.0               0.0  1.739048e+09
# 1               0.0               0.0               0.0  1.739048e+09
# 2               0.0               0.0               0.0  1.739048e+09
# 3               0.0               0.0               0.0  1.739048e+09
# 4               0.0               0.0               0.0  1.739048e+09
#
#    Marker Channel  Timestamp (Formatted)                        Activity
# 0             0.0                    NaN  OpenBCISession_s4-chair squats
# 1             0.0                    NaN  OpenBCISession_s4-chair squats
# 2             0.0                    NaN  OpenBCISession_s4-chair squats
# 3             0.0                    NaN  OpenBCISession_s4-chair squats
# 4             0.0                    NaN  OpenBCISession_s4-chair squats
#
# [5 rows x 34 columns]

# %% [markdown]
# # Display Last Rows of EEG Data

# %%
display(eeg_df.tail())
# Out:
#         Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  \
# 543664         224.0 -187500.022352  -50903.549898    -964.790698
# 543665         226.0 -187500.022352  -51397.612858    -801.824129
# 543666         228.0 -187500.022352  -52053.122467   -1036.830370
# 543667         230.0 -187500.022352  -52375.993416    -875.987217
# 543668         232.0 -187500.022352  -52798.441386   -1042.507713
#
#         EXG Channel 3  EXG Channel 4  EXG Channel 5  EXG Channel 6  \
# 543664 -187500.022352 -171810.058869    4033.238176  -11341.006916
# 543665 -187500.022352 -172259.597154    4038.781409  -11127.279535
# 543666 -187500.022352 -172611.145390    3892.623352  -11407.682169
# 543667 -187500.022352 -172779.655192    3977.470574  -11213.624324
# 543668 -187500.022352 -172956.993932    3886.320160  -11440.673344
#
#         EXG Channel 7  EXG Channel 8  ...  Digital Channel 3 (D17)  \
# 543664 -187500.022352  -19596.489620  ...                      0.0
# 543665 -187500.022352  -19734.645752  ...                      0.0
# 543666 -187500.022352  -19669.624528  ...                      8.0
# 543667 -187500.022352  -19845.957440  ...                      0.0
# 543668 -187500.022352  -19687.841199  ...                      0.0
#
#         Not Used 2  Digital Channel 4 (D18)  Analog Channel 0  \
# 543664         0.0                      0.0               0.0
# 543665         0.0                      0.0               0.0
# 543666         5.0                     16.0               0.0
# 543667         0.0                      0.0               0.0
# 543668         0.0                      0.0               0.0
#
#         Analog Channel 1  Analog Channel 2     Timestamp  Marker Channel  \
# 543664               0.0               0.0  1.739046e+09             0.0
# 543665               0.0               0.0  1.739046e+09             0.0
# 543666               0.0               0.0  1.739046e+09             0.0
# 543667               0.0               0.0  1.739046e+09             0.0
# 543668               0.0               0.0  1.739046e+09             0.0
#
#         Timestamp (Formatted)                         Activity
# 543664                    NaN  OpenBCISession_s4-wall push-ups
# 543665                    NaN  OpenBCISession_s4-wall push-ups
# 543666                    NaN  OpenBCISession_s4-wall push-ups
# 543667                    NaN  OpenBCISession_s4-wall push-ups
# 543668                    NaN  OpenBCISession_s4-wall push-ups
#
# [5 rows x 34 columns]

# %% [markdown]
# # Extract EEG Start and End Timestamps

# %%
eeg_timestamps = eeg_df[['Timestamp', 'Marker Channel']]
start_time = eeg_timestamps['Timestamp'].min()
end_time = eeg_timestamps['Timestamp'].max()
print(f" Extracted EEG activity start and end timestamps:")
print(f" Start Timestamp: {start_time}")
print(f" End Timestamp: {end_time}")
# Out:
#  Extracted EEG activity start and end timestamps:
#  Start Timestamp: 1739044975.962612
#  End Timestamp: 1739048526.121979

# %% [markdown]
# # Load and Filter HAR Data for Subject 4

# %%
har_file_path = "/data0/HAR-datasets/PLHI-HAR_EEG-2025/Combined_Gyro_Acg_Data_Subjects_1_to_6.csv"
har_df = pd.read_csv(har_file_path)

har_df['Timestamp_Accel'] = pd.to_numeric(har_df['Timestamp_Accel'], errors='coerce')
har_df['Timestamp_Gyro'] = pd.to_numeric(har_df['Timestamp_Gyro'], errors='coerce')

if har_df['Timestamp_Accel'].max() > 1e12:  
    har_df['Timestamp_Accel'] = har_df['Timestamp_Accel'] / 1000
    har_df['Timestamp_Gyro'] = har_df['Timestamp_Gyro'] / 1000

print("Before filtering:", har_df.shape)
har_df = har_df[har_df['Subject_ID_x'] == "Subject 4"]
print("After filtering:", har_df.shape)

valid_har = har_df[
    (har_df['Timestamp_Accel'].between(start_time, end_time)) |
    (har_df['Timestamp_Gyro'].between(start_time, end_time))
]

filtered_har = valid_har

print("HAR data is clipped to the EEG activity time range. All activities for Subject 4 are included.")
display(filtered_har.head())
# Out:
# Before filtering: (944460, 12)
# After filtering: (177520, 12)
# HAR data is clipped to the EEG activity time range. All activities for Subject 4 are included.
# /tmp/ipykernel_589598/1884409234.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   har_df = pd.read_csv(har_file_path)
#         Timestamp_Gyro  Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)  \
# 547985    1.739045e+09      0.665843     -0.085521      0.167377
# 547986    1.739045e+09      0.665843     -0.085521      0.167377
# 547987    1.739045e+09      0.665843     -0.085521      0.167377
# 547988    1.739045e+09      0.665843     -0.085521      0.167377
# 547989    1.739045e+09      0.665843     -0.085521      0.167377
#
#              Activity_Label_x Subject_ID_x  Timestamp_Accel  Accel X (g)  \
# 547985  Seated Leg Extensions    Subject 4     1.739045e+09     7.230489
# 547986  Seated Leg Extensions    Subject 4     1.739045e+09     7.230489
# 547987  Seated Leg Extensions    Subject 4     1.739045e+09     7.230489
# 547988  Seated Leg Extensions    Subject 4     1.739045e+09     7.230489
# 547989  Seated Leg Extensions    Subject 4     1.739045e+09     6.904878
#
#        Accel Y (g)  Accel Z (g)       Activity_Label_y Subject_ID_y
# 547985   -6.969521    -0.833182  Seated Leg Extensions    Subject 4
# 547986   -6.969521    -0.833182  Seated Leg Extensions    Subject 4
# 547987   -6.969521    -0.833182  Seated Leg Extensions    Subject 4
# 547988   -6.969521    -0.833182  Seated Leg Extensions    Subject 4
# 547989   -6.236896    -1.319205  Seated Leg Extensions    Subject 4

# %% [markdown]
# # Display Shape and Info of Filtered HAR Data

# %%
print(filtered_har.shape) 
print(filtered_har.info())
# Out:
# (159475, 12)
# <class 'pandas.core.frame.DataFrame'>
# Index: 159475 entries, 547985 to 724899
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Timestamp_Gyro    159475 non-null  float64
#  1   Gyro X (°/s)      159475 non-null  float64
#  2   Gyro Y (°/s)      159455 non-null  float64
#  3   Gyro Z (°/s)      159447 non-null  float64
#  4   Activity_Label_x  159475 non-null  object
#  5   Subject_ID_x      159475 non-null  object
#  6   Timestamp_Accel   159475 non-null  float64
#  7   Accel X (g)       159475 non-null  float64
#  8   Accel Y (g)       159471 non-null  object
#  9   Accel Z (g)       159467 non-null  float64
#  10  Activity_Label_y  159475 non-null  object
#  11  Subject_ID_y      159475 non-null  object
# dtypes: float64(7), object(5)
# memory usage: 15.8+ MB
# None

# %% [markdown]
# # Merge EEG and HAR Data by Timestamp

# %%
eeg_df_sorted = eeg_df.sort_values("Timestamp")
har_df_sorted = filtered_har.sort_values("Timestamp_Accel")

merged_df = pd.merge_asof(
    eeg_df_sorted, 
    har_df_sorted, 
    left_on="Timestamp", 
    right_on="Timestamp_Accel", 
    direction="nearest"
)

print(" EEG & HAR merged.")
display(merged_df.head())
# Out:
#  EEG & HAR merged.
#    Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  EXG Channel 3  \
# 0           6.0 -187500.022352  -61496.645093   -3612.600698 -187500.022352
# 1           8.0 -187500.022352  -62571.205207   -3609.382046 -187500.022352
# 2          10.0 -187500.022352  -63922.077587   -3597.177994 -187500.022352
# 3          12.0 -187500.022352  -65122.388616   -3572.792241 -187500.022352
# 4          14.0 -187500.022352  -66104.412509   -3607.951535 -187500.022352
#
#    EXG Channel 4  EXG Channel 5  EXG Channel 6  EXG Channel 7  EXG Channel 8  \
# 0 -177651.039082   -6056.383974  -19431.489042 -187500.022352  -28378.378258
# 1 -177513.844074   -6162.979443  -19418.077996 -187500.022352  -28387.944804
# 2 -177373.676285   -6238.394229  -19403.839934 -187500.022352  -28359.200461
# 3 -177356.197221   -6116.800739  -19394.519257 -187500.022352  -28366.330667
# 4 -177420.726707   -5992.413281  -19427.264563 -187500.022352  -28374.354944
#
#    ...  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_x  Subject_ID_x  \
# 0  ...     -0.085521      0.167377  Seated Leg Extensions     Subject 4
# 1  ...     -0.085521      0.167377  Seated Leg Extensions     Subject 4
# 2  ...     -0.085521      0.167377  Seated Leg Extensions     Subject 4
# 3  ...     -0.085521      0.167377  Seated Leg Extensions     Subject 4
# 4  ...     -0.085521      0.167377  Seated Leg Extensions     Subject 4
#
#    Timestamp_Accel  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0     1.739045e+09     7.230489    -6.969521    -0.833182
# 1     1.739045e+09     7.230489    -6.969521    -0.833182
# 2     1.739045e+09     7.230489    -6.969521    -0.833182
# 3     1.739045e+09     7.230489    -6.969521    -0.833182
# 4     1.739045e+09     7.230489    -6.969521    -0.833182
#
#         Activity_Label_y  Subject_ID_y
# 0  Seated Leg Extensions     Subject 4
# 1  Seated Leg Extensions     Subject 4
# 2  Seated Leg Extensions     Subject 4
# 3  Seated Leg Extensions     Subject 4
# 4  Seated Leg Extensions     Subject 4
#
# [5 rows x 46 columns]

# %% [markdown]
# # Check Timestamp Alignment

# %%
print("Timestamp alignment (EEG vs HAR):")
print(merged_df[['Timestamp', 'Timestamp_Accel']])
# Out:
# Timestamp alignment (EEG vs HAR):
#            Timestamp  Timestamp_Accel
# 0       1.739045e+09     1.739045e+09
# 1       1.739045e+09     1.739045e+09
# 2       1.739045e+09     1.739045e+09
# 3       1.739045e+09     1.739045e+09
# 4       1.739045e+09     1.739045e+09
# ...              ...              ...
# 543664  1.739049e+09     1.739049e+09
# 543665  1.739049e+09     1.739049e+09
# 543666  1.739049e+09     1.739049e+09
# 543667  1.739049e+09     1.739049e+09
# 543668  1.739049e+09     1.739049e+09
#
# [543669 rows x 2 columns]

# %% [markdown]
# # Show Merged Data Columns

# %%
print("Unique Columns in Merged Data:")
print(merged_df.columns)
# Out:
# Unique Columns in Merged Data:
# Index(['Sample Index', 'EXG Channel 0', 'EXG Channel 1', 'EXG Channel 2',
#        'EXG Channel 3', 'EXG Channel 4', 'EXG Channel 5', 'EXG Channel 6',
#        'EXG Channel 7', 'EXG Channel 8', 'EXG Channel 9', 'EXG Channel 10',
#        'EXG Channel 11', 'EXG Channel 12', 'EXG Channel 13', 'EXG Channel 14',
#        'EXG Channel 15', 'Accel Channel 0', 'Accel Channel 1',
#        'Accel Channel 2', 'Not Used 1', 'Digital Channel 0 (D11)',
#        'Digital Channel 1 (D12)', 'Digital Channel 2 (D13)',
#        'Digital Channel 3 (D17)', 'Not Used 2', 'Digital Channel 4 (D18)',
#        'Analog Channel 0', 'Analog Channel 1', 'Analog Channel 2', 'Timestamp',
#        'Marker Channel', 'Timestamp (Formatted)', 'Activity', 'Timestamp_Gyro',
#        'Gyro X (°/s)', 'Gyro Y (°/s)', 'Gyro Z (°/s)', 'Activity_Label_x',
#        'Subject_ID_x', 'Timestamp_Accel', 'Accel X (g)', 'Accel Y (g)',
#        'Accel Z (g)', 'Activity_Label_y', 'Subject_ID_y'],
#       dtype='object')

# %% [markdown]
# # Display Final Merged Data

# %%
display(merged_df)
# Out:
#         Sample Index  EXG Channel 0  EXG Channel 1  EXG Channel 2  \
# 0                6.0 -187500.022352  -61496.645093   -3612.600698
# 1                8.0 -187500.022352  -62571.205207   -3609.382046
# 2               10.0 -187500.022352  -63922.077587   -3597.177994
# 3               12.0 -187500.022352  -65122.388616   -3572.792241
# 4               14.0 -187500.022352  -66104.412509   -3607.951535
# ...              ...            ...            ...            ...
# 543664          70.0 -187500.022352 -187500.022352  -63766.598852
# 543665          70.0 -187500.022352 -187500.022352  -63766.598852
# 543666          70.0 -187500.022352 -187500.022352  -63766.598852
# 543667          70.0 -187500.022352 -187500.022352  -63766.598852
# 543668          70.0 -187500.022352 -187500.022352  -63766.598852
#
#         EXG Channel 3  EXG Channel 4  EXG Channel 5  EXG Channel 6  \
# 0      -187500.022352 -177651.039082   -6056.383974  -19431.489042
# 1      -187500.022352 -177513.844074   -6162.979443  -19418.077996
# 2      -187500.022352 -177373.676285   -6238.394229  -19403.839934
# 3      -187500.022352 -177356.197221   -6116.800739  -19394.519257
# 4      -187500.022352 -177420.726707   -5992.413281  -19427.264563
# ...               ...            ...            ...            ...
# 543664 -187500.022352 -187500.022352  -49210.628773  -74359.179957
# 543665 -187500.022352 -187500.022352  -49210.628773  -74359.179957
# 543666 -187500.022352 -187500.022352  -49210.628773  -74359.179957
# 543667 -187500.022352 -187500.022352  -49210.628773  -74359.179957
# 543668 -187500.022352 -187500.022352  -49210.628773  -74359.179957
#
#         EXG Channel 7  EXG Channel 8  ...  Gyro Y (°/s)  Gyro Z (°/s)  \
# 0      -187500.022352  -28378.378258  ...     -0.085521      0.167377
# 1      -187500.022352  -28387.944804  ...     -0.085521      0.167377
# 2      -187500.022352  -28359.200461  ...     -0.085521      0.167377
# 3      -187500.022352  -28366.330667  ...     -0.085521      0.167377
# 4      -187500.022352  -28374.354944  ...     -0.085521      0.167377
# ...               ...            ...  ...           ...           ...
# 543664 -187500.022352  -87247.709900  ...      0.041539      0.007330
# 543665 -187500.022352  -87247.709900  ...      0.041539      0.007330
# 543666 -187500.022352  -87247.709900  ...      0.041539      0.007330
# 543667 -187500.022352  -87247.709900  ...      0.041539      0.007330
# 543668 -187500.022352  -87247.709900  ...      0.041539      0.007330
#
#                 Activity_Label_x  Subject_ID_x  Timestamp_Accel  Accel X (g)  \
# 0          Seated Leg Extensions     Subject 4     1.739045e+09     7.230489
# 1          Seated Leg Extensions     Subject 4     1.739045e+09     7.230489
# 2          Seated Leg Extensions     Subject 4     1.739045e+09     7.230489
# 3          Seated Leg Extensions     Subject 4     1.739045e+09     7.230489
# 4          Seated Leg Extensions     Subject 4     1.739045e+09     7.230489
# ...                          ...           ...              ...          ...
# 543664  Light Stationary Cycling     Subject 4     1.739049e+09     4.510676
# 543665  Light Stationary Cycling     Subject 4     1.739049e+09     4.510676
# 543666  Light Stationary Cycling     Subject 4     1.739049e+09     4.510676
# 543667  Light Stationary Cycling     Subject 4     1.739049e+09     4.510676
# 543668  Light Stationary Cycling     Subject 4     1.739049e+09     4.510676
#
#         Accel Y (g)  Accel Z (g)          Activity_Label_y  Subject_ID_y
# 0         -6.969521    -0.833182     Seated Leg Extensions     Subject 4
# 1         -6.969521    -0.833182     Seated Leg Extensions     Subject 4
# 2         -6.969521    -0.833182     Seated Leg Extensions     Subject 4
# 3         -6.969521    -0.833182     Seated Leg Extensions     Subject 4
# 4         -6.969521    -0.833182     Seated Leg Extensions     Subject 4
# ...             ...          ...                       ...           ...
# 543664    -3.981557     8.068459  Light Stationary Cycling     Subject 4
# 543665    -3.981557     8.068459  Light Stationary Cycling     Subject 4
# 543666    -3.981557     8.068459  Light Stationary Cycling     Subject 4
# 543667    -3.981557     8.068459  Light Stationary Cycling     Subject 4
# 543668    -3.981557     8.068459  Light Stationary Cycling     Subject 4
#
# [543669 rows x 46 columns]

# %% [markdown]
# # Save Merged Data to CSV

# %%
try:
    merged_df.to_csv("EEG-HAR_Subject_4_Merged.csv", index=False)
    print("File saved successfully as EEG-HAR_Subject_4_Merged.csv.")
except Exception as e:
    print(f"An error occurred while saving the file: {e}")
# Out:
# File saved successfully as EEG-HAR_Subject_4_Merged.csv.
